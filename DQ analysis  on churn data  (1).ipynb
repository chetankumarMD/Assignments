# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
md= pd.read_excel('churn data.xlsx')
md.head(10)
# Out:
#   Customer_ID Gender  Age Connect_Date      L_O_S  Dropped_Calls  tariff  \
# 0     K100010      M   46   1999-07-18  15.066667              1  CAT 50
# 1     K100020      M   27   1997-09-18  37.333333              0  CAT 50
# 2     K100030      M   39   1996-08-23  50.366667              2  CAT 50
# 3     K100040      M   28   1998-08-18  26.200000              2  CAT 50
# 4     K100070      M   38   1999-10-14  12.133333              1  CAT 50
# 5     K100080      M   27   1998-01-20  33.200000              0  CAT 50
# 6     K100090      M   38   1996-05-31  53.166667              1  CAT 50
# 7     K100100      M   48   1996-07-28  51.233333              0  CAT 50
# 8     K100110      M   34   1998-12-11  22.366667              2  CAT 50
# 9     K100120      M   32   1997-11-06  35.700000              0  CAT 50
#
#      Churn Handset  Peak_calls_Sum  ...  National_mins  AveNational  \
# 0  Churned   SOP10              14  ...      58.637756     1.221620
# ...

# %%
md.shape
# Out:
# (24999, 31)

# %%
print(md.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24999 entries, 0 to 24998
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             24999 non-null  object
#  1   Gender                  24999 non-null  object
#  2   Age                     24999 non-null  int64
#  3   Connect_Date            24999 non-null  datetime64[ns]
#  4   L_O_S                   24999 non-null  float64
#  5   Dropped_Calls           24999 non-null  int64
#  6   tariff                  24999 non-null  object
#  7   Churn                   24999 non-null  object
#  8   Handset                 24999 non-null  object
#  9   Peak_calls_Sum          24999 non-null  int64
#  10  Peak_mins_Sum           24999 non-null  float64
#  11  OffPeak_calls_Sum       24999 non-null  int64
#  12  OffPeak_mins_Sum        24999 non-null  float64
#  13  Weekend_calls_Sum       24999 non-null  int64
# ...

# %% [markdown]
# ### Data Consistency

# %%
md.dtypes  ## verifing the data type
# Out:
# Customer_ID                       object
# Gender                            object
# Age                                int64
# Connect_Date              datetime64[ns]
# L_O_S                            float64
# Dropped_Calls                      int64
# tariff                            object
# Churn                             object
# Handset                           object
# Peak_calls_Sum                     int64
# Peak_mins_Sum                    float64
# OffPeak_calls_Sum                  int64
# OffPeak_mins_Sum                 float64
# Weekend_calls_Sum                  int64
# Weekend_mins_Sum                 float64
# International_mins_Sum           float64
# Nat_call_cost_Sum                float64
# AvePeak                          float64
# AveOffPeak                       float64
# AveWeekend                       float64
# National_calls                     int64
# National_mins                    float64
# AveNational                      float64
# ...

# %%
print(md['Gender'].value_counts())     # Check unique values in a categorical column
# Out:
# Gender
# F    12523
# M    12476
# Name: count, dtype: int64

# %% [markdown]
# ### Data Completeness

# %%
missing_values = md.isnull().sum()
print("Missing Values:\n", missing_values)   # Check for missing values
# Out:
# Missing Values:
#  Customer_ID                0
# Gender                     0
# Age                        0
# Connect_Date               0
# L_O_S                      0
# Dropped_Calls              0
# tariff                     0
# Churn                      0
# Handset                    0
# Peak_calls_Sum             0
# Peak_mins_Sum              0
# OffPeak_calls_Sum          0
# OffPeak_mins_Sum           0
# Weekend_calls_Sum          0
# Weekend_mins_Sum           0
# International_mins_Sum     0
# Nat_call_cost_Sum          0
# AvePeak                    0
# AveOffPeak                 0
# AveWeekend                 0
# National_calls             0
# National_mins              0
# AveNational                0
# All_calls_mins             0
# Usage_Band                 0
# Mins_charge                0
# call_cost_per_min         18
# actual_call_cost           0
# Total_call_cost            0
# Total_Cost                 0
# average_cost_min           0
# dtype: int64

# %% [markdown]
# ### Data Accuracy

# %%
duplicates = md.duplicated().sum()
print(f"Number of duplicate entries: {duplicates}")  # Check for duplicates
# Out:
# Number of duplicate entries: 0

# %% [markdown]
# ### Data Timeliness

# %%
print("Data date range:", md['Connect_Date'].min(), "to", md['Connect_Date'].max())    # Assuming 'churn_date' is a datetime column
# Out:
# Data date range: 1996-01-01 00:00:00 to 1999-12-31 00:00:00

# %% [markdown]
# ### Data Redundancy

# %%
md1= md.drop_duplicates()     # Remove duplicates if necessary
md1
# Out:
#       Customer_ID Gender  Age Connect_Date      L_O_S  Dropped_Calls   tariff  \
# 0         K100010      M   46   1999-07-18  15.066667              1   CAT 50
# 1         K100020      M   27   1997-09-18  37.333333              0   CAT 50
# 2         K100030      M   39   1996-08-23  50.366667              2   CAT 50
# 3         K100040      M   28   1998-08-18  26.200000              2   CAT 50
# 4         K100070      M   38   1999-10-14  12.133333              1   CAT 50
# ...           ...    ...  ...          ...        ...            ...      ...
# 24994     K356720      M   49   1997-04-08  42.766667              0  CAT 200
# 24995     K356730      F   22   1998-07-13  27.400000              0  CAT 200
# 24996     K356740      M   13   1998-06-03  28.733333              7  CAT 200
# 24997     K356750      M   58   1999-06-23  15.900000              0  CAT 200
# 24998     K356760      F   17   1999-11-13  11.133333              2  CAT 200
#
# ...

# %%
md1.shape
# Out:
# (24999, 31)

# %% [markdown]
# ### Summarize DQ Findings

# %%
summary=md1.describe()
print(summary)
# Out:
#                 Age                   Connect_Date         L_O_S  \
# count  24999.000000                          24999  24999.000000
# mean      30.348774  1998-01-16 23:09:39.335173504     33.301165
# min       12.000000            1996-01-01 00:00:00      9.533333
# 25%       20.000000            1997-01-11 00:00:00     20.533333
# 50%       28.000000            1998-01-18 00:00:00     33.266667
# 75%       38.000000            1999-02-04 00:00:00     45.666667
# max       82.000000            1999-12-31 00:00:00     58.200000
# std       12.835550                            NaN     14.255039
#
#        Dropped_Calls  Peak_calls_Sum  Peak_mins_Sum  OffPeak_calls_Sum  \
# count   24999.000000    24999.000000   24999.000000       24999.000000
# mean        2.443538      244.262090     724.225398          96.467099
# min         0.000000        0.000000       0.000000           0.000000
# 25%         0.000000       57.000000     327.000000          25.000000
# ...

# %%
iqr_report = {}

# %%
for column in md1.select_dtypes(include=['float64', 'int64']).columns:
    Q1 = md1[column].quantile(0.25)
    Q3 = md1[column].quantile(0.75)
    IQR = Q3 - Q1
    iqr_report[column] = {
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': Q1 - 1.5 * IQR,
        'Upper Bound': Q3 + 1.5 * IQR}

# %%
iqr_report_df = pd.DataFrame.from_dict(iqr_report, orient='index')

# %%
print(iqr_report_df)
# Out:
#                                 Q1           Q3         IQR  Lower Bound  \
# Age                      20.000000    38.000000   18.000000    -7.000000
# L_O_S                    20.533333    45.666667   25.133334   -17.166668
# Dropped_Calls             0.000000     2.000000    2.000000    -3.000000
# Peak_calls_Sum           57.000000   355.000000  298.000000  -390.000000
# Peak_mins_Sum           327.000000  1035.600000  708.600000  -735.900000
# OffPeak_calls_Sum        25.000000   141.000000  116.000000  -149.000000
# OffPeak_mins_Sum        132.600000   415.800000  283.200000  -292.200000
# Weekend_calls_Sum         4.000000    22.000000   18.000000   -23.000000
# Weekend_mins_Sum         20.000000    68.499999   48.499999   -52.749999
# International_mins_Sum   73.157046   268.658402  195.501356  -220.094988
# Nat_call_cost_Sum         0.000000    32.913703   32.913703   -49.370555
# AvePeak                   1.979345     5.752941    3.773595    -3.681048
# ...

# %%
numerical_columns = md.select_dtypes(include=['float64', 'int64'])

# %%
percentiles = [0.01, 0.05, 0.1, 0.9, 0.95, 0.99]
percentile_values = numerical_columns.quantile(percentiles)

# %%
print("Percentiles (1%, 5%, 10%, 90%, 95%, 99%) for each numerical column:")
percentile_values
# Out:
# Percentiles (1%, 5%, 10%, 90%, 95%, 99%) for each numerical column:
#        Age      L_O_S  Dropped_Calls  Peak_calls_Sum  Peak_mins_Sum  \
# 0.01  12.0  10.000000            0.0             1.0      25.196174
# 0.05  14.0  12.000000            0.0            10.0      66.000000
# 0.10  16.0  13.900000            0.0            20.0     106.199999
# 0.90  49.0  53.166667            8.0           579.0    1439.399999
# 0.95  55.0  55.733333           10.0           742.0    1705.200000
# 0.99  66.0  57.733333           11.0          1078.0    2353.200000
#
#       OffPeak_calls_Sum  OffPeak_mins_Sum  Weekend_calls_Sum  \
# 0.01               0.00          0.000000                0.0
# 0.05               4.00         33.299999                0.0
# 0.10               8.00         55.439999                1.0
# 0.90             231.00        570.599999               38.0
# 0.95             288.00        645.930000               50.0
# ...
